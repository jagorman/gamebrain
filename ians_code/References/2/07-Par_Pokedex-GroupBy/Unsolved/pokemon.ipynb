# %%
# Dependencies
import pandas as pd

# %%
# Save file path to variable
file = "Resources/Pokemon.csv"

# %%
# Read with Pandas
poke_df = pd.read_csv(file)

# %%
poke_df
new_df = poke_df[["Name", "Type 1", "HP", "Attack", "Sp. Atk", "Sp. Def", "Speed"]]
#This sets a new dataframe with the below extractions
poke_df
# Out:
#                       Name   Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0                Bulbasaur    Grass  45      49       49       65       65
# 1                  Ivysaur    Grass  60      62       63       80       80
# 2                 Venusaur    Grass  80      82       83      100      100
# 3    VenusaurMega Venusaur    Grass  80     100      123      122      120
# 4               Charmander     Fire  39      52       43       60       50
# ..                     ...      ...  ..     ...      ...      ...      ...
# 795                Diancie     Rock  50     100      150      100      150
# 796    DiancieMega Diancie     Rock  50     160      110      160      110
# 797    HoopaHoopa Confined  Psychic  80     110       60      150      130
# 798     HoopaHoopa Unbound  Psychic  80     160       60      170      130
# 799              Volcanion     Fire  80     110      120      130       90
#
#      Speed
# 0       45
# 1       60
# 2       80
# 3       80
# ...

# %%
# Extract the following columns: "Type 1", "HP", "Attack", "Sp. Atk", "Sp. Def", and "Speed"
#Another way to create the new dataframe by modifying existing
del poke_df["Type 2"]
del poke_df["Generation"]
del poke_df["#"]
del poke_df["Legendary"]
del poke_df["Total"]
poke_df.head(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Type 2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-ee9a428baeee> in <module>
# ...

# %%
new_df.head(3)
# Out:
#         Name Type 1  HP  Attack  Sp. Atk  Sp. Def  Speed
# 0  Bulbasaur  Grass  45      49       65       65     45
# 1    Ivysaur  Grass  60      62       80       80     60
# 2   Venusaur  Grass  80      82      100      100     80

# %%
# Create a dataframe of the average stats for each type of pokemon.
poke_group = new_df.groupby(["Type 1"])

poke_stats_df = poke_group.mean()
poke_stats_df
# Out:
#                  HP      Attack    Sp. Atk    Sp. Def       Speed
# Type 1
# Bug       56.884058   70.971014  53.869565  64.797101   61.681159
# Dark      66.806452   88.387097  74.645161  69.516129   76.161290
# Dragon    83.312500  112.125000  96.843750  88.843750   83.031250
# Electric  59.795455   69.090909  90.022727  73.704545   84.500000
# Fairy     74.117647   61.529412  78.529412  84.705882   48.588235
# Fighting  69.851852   96.777778  53.111111  64.703704   66.074074
# Fire      69.903846   84.769231  88.980769  72.211538   74.442308
# Flying    70.750000   78.750000  94.250000  72.500000  102.500000
# Ghost     64.437500   73.781250  79.343750  76.468750   64.343750
# Grass     67.271429   73.214286  77.500000  70.428571   61.928571
# Ground    73.781250   95.750000  56.468750  62.750000   63.906250
# Ice       72.000000   72.750000  77.541667  76.291667   63.458333
# Normal    77.275510   73.469388  55.816327  63.724490   71.551020
# ...

# %%
# Calculate the total power level of each type of pokemon by summing all of the stats together.
# Place the results into a new column.
# Hint: Research the sum method from pandas.
poke_stats_df["Total Power"] = poke_stats_df.sum(axis=1)
#(axis=1) switches the sum from columns to rows
poke_stats_df
# Out:
#                  HP      Attack    Sp. Atk    Sp. Def       Speed  Total Power
# Type 1
# Bug       56.884058   70.971014  53.869565  64.797101   61.681159   616.405797
# Dark      66.806452   88.387097  74.645161  69.516129   76.161290   751.032258
# Dragon    83.312500  112.125000  96.843750  88.843750   83.031250   928.312500
# Electric  59.795455   69.090909  90.022727  73.704545   84.500000   754.227273
# Fairy     74.117647   61.529412  78.529412  84.705882   48.588235   694.941176
# Fighting  69.851852   96.777778  53.111111  64.703704   66.074074   701.037037
# Fire      69.903846   84.769231  88.980769  72.211538   74.442308   780.615385
# Flying    70.750000   78.750000  94.250000  72.500000  102.500000   837.500000
# Ghost     64.437500   73.781250  79.343750  76.468750   64.343750   716.750000
# Grass     67.271429   73.214286  77.500000  70.428571   61.928571   700.685714
# Ground    73.781250   95.750000  56.468750  62.750000   63.906250   705.312500
# ...

# %%
# Bonus: Sort the table by strongest type and export the resulting table to a new CSV.
sorted_df = poke_stats_df.sort_values("Total Power",ascending=False)
#ascending=False puts strongest at the top
sorted_df
# Out:
#                  HP      Attack    Sp. Atk    Sp. Def       Speed  Total Power
# Type 1
# Dragon    83.312500  112.125000  96.843750  88.843750   83.031250   928.312500
# Flying    70.750000   78.750000  94.250000  72.500000  102.500000   837.500000
# Psychic   70.631579   71.456140  98.403509  86.280702   81.491228   816.526316
# Fire      69.903846   84.769231  88.980769  72.211538   74.442308   780.615385
# Electric  59.795455   69.090909  90.022727  73.704545   84.500000   754.227273
# Dark      66.806452   88.387097  74.645161  69.516129   76.161290   751.032258
# Ice       72.000000   72.750000  77.541667  76.291667   63.458333   724.083333
# Steel     65.222222   92.703704  67.518519  80.629630   55.259259   722.666667
# Ghost     64.437500   73.781250  79.343750  76.468750   64.343750   716.750000
# Water     72.062500   74.151786  74.812500  70.517857   65.964286   715.017857
# Rock      65.363636   92.863636  63.340909  75.477273   55.909091   705.909091
# ...

# %%
sorted_df.to_csv("poke.csv")
