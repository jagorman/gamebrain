# %%
# Import Dependencies
import pandas as pd

# %%
# Reference the file where the CSV is located
file = 'Resources/crime_incident_data2017.csv'
# Import the data into a Pandas DataFrame
df = pd.read_csv(file, encoding="ISO-8859-1")

# %%
df
# Out:
#                             Address  Case Number Crime Against  \
# 0                               NaN  17-X4762181        Person
# 1                               NaN  17-X4757824      Property
# 2          200 BLOCK OF SE 78TH AVE    17-900367      Property
# 3                               NaN  17-X4748982      Property
# 4                               NaN  17-X4748982      Property
# ...                             ...          ...           ...
# 41027   8800 BLOCK OF NE SANDY BLVD    17-285386       Society
# 41028     9700 BLOCK OF SE STARK ST    17-286082       Society
# 41029     9700 BLOCK OF SE STARK ST    17-286413       Society
# 41030               UNKNOWN ADDRESS    17-286445       Society
# 41031  8000 BLOCK OF SE POWELL BLVD    17-286659       Society
#
#           Neighborhood  Number of Records Occur Date Occur Month Year  \
# 0                  NaN                  1     1/1/96           1/1/96
# ...

# %%
# look for missing values
df.count()
# Out:
# Address              37365
# Case Number          41032
# Crime Against        41032
# Neighborhood         39712
# Number of Records    41032
# Occur Date           41032
# Occur Month Year     41032
# Occur Time           41032
# Offense Category     41032
# Offense Count        41032
# Offense Type         41032
# Open Data Lat        36712
# Open Data Lon        36712
# Open Data X          36712
# Open Data Y          36712
# Report Date          41032
# Report Month Year    41032
# dtype: int64

# %%
# drop null rows
cleaned_df = df.dropna(how='any')

# %%
# verify counts
cleaned_df.count()
# Out:
# Address              36146
# Case Number          36146
# Crime Against        36146
# Neighborhood         36146
# Number of Records    36146
# Occur Date           36146
# Occur Month Year     36146
# Occur Time           36146
# Offense Category     36146
# Offense Count        36146
# Offense Type         36146
# Open Data Lat        36146
# Open Data Lon        36146
# Open Data X          36146
# Open Data Y          36146
# Report Date          36146
# Report Month Year    36146
# dtype: int64

# %%
# Check to see if there are any values with mispelled or similar values in "Offense Type"
cleaned_df['Offense Type'].value_counts()
# Out:
# Motor Vehicle Theft                           12709
# Burglary                                       6769
# All Other Larceny                              4558
# Vandalism                                      3863
# Identity Theft                                 1794
# Simple Assault                                 1216
# Drug/Narcotic Violations                       1095
# Intimidation                                    900
# False Pretenses/Swindle/Confidence Game         870
# Aggravated Assault                              839
# Counterfeiting/Forgery                          448
# Weapons Law Violations                          266
# Credit Card/ATM Fraud                           226
# Arson                                           200
# Prostitution                                    145
# Embezzlement                                     73
# Stolen Property Offenses                         57
# Kidnapping/Abduction                             22
# ...

# %%
# Combine similar offenses
#Real world you would clarify what would be grouped together before grouping
cleaned_df['Offense Type'] = cleaned_df['Offense Type'].replace(
    {'Theft From Motor Vehicle': 'Motor Vehicle Theft', 'Theft of Motor Vehicle Parts or Accessories': 'Motor Vehicle Theft'})
cleaned_df['Offense Type'] = cleaned_df['Offense Type'].replace(
    {'Robbery': 'Burglary', 'Shoplifting': 'Burglary','Pocket-Picking': 'Burglary','Purse-Snatching': 'Burglary','Theft From Building': 'Burglary',})
# Out:
# <ipython-input-11-78260afa4ab7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['Offense Type'] = cleaned_df['Offense Type'].replace(
# <ipython-input-11-78260afa4ab7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['Offense Type'] = cleaned_df['Offense Type'].replace(

# %%
# Check to see if you comnbined similar offenses correctly in "Offense Type".
#Just re-did step above

# %%
# Create a new DataFrame that looks into a specific neighborhood
Sumner_df = cleaned_df.loc[cleaned_df["Neighborhood"] == "Sumner", : ]
Sumner_df
# Out:
#                                  Address Case Number Crime Against  \
# 330            4400 BLOCK OF NE 83RD AVE   17-900221      Property
# 355          8200 BLOCK OF NE SANDY BLVD   17-900267      Property
# 469            8200 BLOCK OF NE GOING ST    17-22551      Property
# 676          8200 BLOCK OF NE SANDY BLVD     17-1697      Property
# 952          8800 BLOCK OF NE SANDY BLVD   17-900208      Property
# ...                                  ...         ...           ...
# 40253  8900 BLOCK OF NE KILLINGSWORTH ST   17-802917      Property
# 40421        8800 BLOCK OF NE SANDY BLVD   17-281677      Property
# 40575        NE 82ND AVE / NE SANDY BLVD   17-282862      Property
# 40998     8400 BLOCK OF NE COLUMBIA BLVD   17-912758      Property
# 41027        8800 BLOCK OF NE SANDY BLVD   17-285386       Society
#
#       Neighborhood  Number of Records Occur Date Occur Month Year  Occur Time  \
# 330         Sumner                  1   12/10/16          12/1/16        1112
# ...
